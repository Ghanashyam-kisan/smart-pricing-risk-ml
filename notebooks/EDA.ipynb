# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/pricing_data.csv")
df.head()
# Out:
#    age  income  credit_score  claim_history  vehicle_value  price
# 0   56  636221           826              0         524592  10650
# 1   46  605975           696              1        1172552  29506
# 2   32  512146           641              2         621098  30321
# 3   60  990853           629              2         571929  16392
# 4   25  395392           726              2         265813  17076

# %%
df.describe()
# Out:
#               age        income  credit_score  claim_history  vehicle_value  \
# count  5000.00000  5.000000e+03    5000.00000    5000.000000   5.000000e+03
# mean     41.16820  5.965453e+05     699.42780       1.243800   8.029287e+05
# std      13.53105  2.454086e+05      78.42266       1.121701   2.950118e+05
# min      18.00000  1.500000e+05     386.00000       0.000000   2.000000e+05
# 25%      29.00000  4.198988e+05     647.75000       0.000000   5.904425e+05
# 50%      41.00000  5.908530e+05     699.00000       1.000000   7.994890e+05
# 75%      53.00000  7.663450e+05     752.00000       2.000000   1.000142e+06
# max      64.00000  1.581559e+06     900.00000       6.000000   1.906240e+06
#
#              price
# count   5000.00000
# mean   28511.66480
# std    11309.52571
# min     8000.00000
# 25%    20471.50000
# 50%    27863.50000
# 75%    36091.25000
# max    69960.00000

# %%
plt.figure()
sns.histplot(df["price"], bins=40)
plt.title("Price Distribution")
plt.show()

# %%
features = ["income", "credit_score", "claim_history", "vehicle_value"]

for col in features:
    plt.figure()
    sns.scatterplot(x=df[col], y=df["price"])
    plt.title(f"{col} vs Price")
    plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Matrix")
plt.show()
